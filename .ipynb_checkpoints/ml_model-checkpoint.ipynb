# %%
import pandas as pd
import numpy as np
import csv as csv
import pickle
from sklearn.utils import shuffle
from sklearn.cross_validation import train_test_split
from sklearn import metrics, svm, neighbors, linear_model, tree
from sklearn.grid_search import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestClassifier
from datetime import datetime
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# D:\Anaconda\lib\site-packages\sklearn\utils\fixes.py:64: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if 'order' in inspect.getargspec(np.copy)[0]:

# %%
with open('ddos_df_pickled.pickle', 'rb') as handle:
    b = pickle.load(handle)
b.head()
# Out:
#                src            dst label  total_out_bytes_rate  \
# 1     195.216.1.86  71.126.222.64  ddos           7996.798079
# 2   195.52.240.138  71.126.222.64  ddos           6958.368734
# 4  209.210.127.200  71.126.222.64  ddos           8236.994220
# 5     167.46.3.209  71.126.222.64  ddos           5860.023725
# 6   217.238.32.123  71.126.222.64  ddos           5798.984772
#
#    total_out_frames_rate  icmp_out_bytes_rate  icmp_out_frames_rate  \
# 1             148.088853          4709.376326             78.489605
# 2             127.442651          4205.607477             70.093458
# 4             142.100193          7080.924855            118.015414
# 5             108.738632          3202.846975             53.380783
# 6             107.614213          3273.185061             54.553084
#
#    tcp_out_bytes_rate  tcp_out_frames_rate  with_tcpsyn_out_bytes_rate  \
# 1         3699.229327            77.067278                 3699.229327
# 2         2753.346080            57.361377                 2753.346080
# 4         1230.453730            25.634453                 1230.453730
# 5         2886.597938            60.137457                 2886.597938
# 6         2694.386694            56.133056                 2694.386694
#
#    with_tcpsyn_out_frames_rate  tcp_ports_used
# 1                    77.067278              37
# 2                    57.361377              27
# 4                    25.634453              10
# 5                    60.137457              23
# 6                    56.133056              23

# %%
shuffled = shuffle(b)
shuffled.head()
# Out:
#                   src            dst label  total_out_bytes_rate  \
# 3644    215.194.64.94  71.126.222.64  ddos           1641.212674
# 286     203.10.74.140  71.126.222.64  ddos           3017.361804
# 3746     203.78.6.225  71.126.222.64  ddos           1560.468140
# 2620   153.54.193.200  71.126.222.64  ddos           1976.935750
# 4388  167.156.174.166  71.126.222.64  ddos           1324.178519
#
#       total_out_frames_rate  icmp_out_bytes_rate  icmp_out_frames_rate  \
# 3644              29.633007          1904.006347             31.733439
# 286               55.877070          1735.537190             28.925620
# 3746              26.007802          1560.468140             26.007802
# 2620              32.948929          1976.935750             32.948929
# 4388              22.069642          1324.178519             22.069642
#
#       tcp_out_bytes_rate  tcp_out_frames_rate  with_tcpsyn_out_bytes_rate  \
# 3644          547.070891            11.397310                  547.070891
# 286          1402.629931            29.221457                 1402.629931
# 3746            0.000000             0.000000                    0.000000
# 2620            0.000000             0.000000                    0.000000
# 4388            0.000000             0.000000                    0.000000
#
#       with_tcpsyn_out_frames_rate  tcp_ports_used
# 3644                    11.397310               5
# 286                     29.221457              14
# 3746                     0.000000               0
# 2620                     0.000000               0
# 4388                     0.000000               0

# %%
x_train, x_test = train_test_split(shuffled, test_size=0.3)
x_train.head()
# Out:
#                   src            dst label  total_out_bytes_rate  \
# 1962    203.209.15.60  71.126.222.64  ddos           2373.104812
# 3623  118.190.110.108  71.126.222.64  ddos           1646.466956
# 1733    195.36.47.139  71.126.222.64  ddos           2373.516552
# 2522   202.243.166.55  71.126.222.64  ddos           1963.350785
# 229     255.3.231.160  71.126.222.64  ddos           3305.389222
#
#       total_out_frames_rate  icmp_out_bytes_rate  icmp_out_frames_rate  \
# 1962              39.551747          2373.104812             39.551747
# 3623              27.441116          1646.466956             27.441116
# 1733              39.558609          2373.516552             39.558609
# 2522              32.722513          1963.350785             32.722513
# 229               61.876248          1680.336067             28.005601
#
#       tcp_out_bytes_rate  tcp_out_frames_rate  with_tcpsyn_out_bytes_rate  \
# 1962            0.000000             0.000000                    0.000000
# 3623            0.000000             0.000000                    0.000000
# 1733            0.000000             0.000000                    0.000000
# 2522            0.000000             0.000000                    0.000000
# 229          1631.673665            33.993201                 1631.673665
#
#       with_tcpsyn_out_frames_rate  tcp_ports_used
# 1962                     0.000000               0
# 3623                     0.000000               0
# 1733                     0.000000               0
# 2522                     0.000000               0
# 229                     33.993201              17

# %%
x_test.head()
# Out:
#                   src            dst label  total_out_bytes_rate  \
# 5423   203.135.164.77  71.126.222.64  ddos           1463.414634
# 3938      90.5.82.149  71.126.222.64  ddos           1811.047389
# 5549  167.120.200.112  71.126.222.64  ddos              0.000000
# 1937    192.58.210.21  71.126.222.64  ddos           2308.678923
# 2337   194.68.197.214  71.126.222.64  ddos           2122.347066
#
#       total_out_frames_rate  icmp_out_bytes_rate  icmp_out_frames_rate  \
# 5423              24.390244          1463.414634             24.390244
# 3938              30.184123          1811.047389             30.184123
# 5549               0.000000             0.000000              0.000000
# 1937              38.477982          2308.678923             38.477982
# 2337              35.372451          2122.347066             35.372451
#
#       tcp_out_bytes_rate  tcp_out_frames_rate  with_tcpsyn_out_bytes_rate  \
# 5423                   0                    0                           0
# 3938                   0                    0                           0
# 5549                   0                    0                           0
# 1937                   0                    0                           0
# 2337                   0                    0                           0
#
#       with_tcpsyn_out_frames_rate  tcp_ports_used
# 5423                            0               0
# 3938                            0               0
# 5549                            0               0
# 1937                            0               0
# 2337                            0               0

# %%
#features to use for training
features = list(x_train.dtypes.index)
not_features = ['src', 'dst', 'label']
for item in not_features:
    features.remove(item)
print (features)
# Out:
# ['total_out_bytes_rate', 'total_out_frames_rate', 'icmp_out_bytes_rate', 'icmp_out_frames_rate', 'tcp_out_bytes_rate', 'tcp_out_frames_rate', 'with_tcpsyn_out_bytes_rate', 'with_tcpsyn_out_frames_rate', 'tcp_ports_used']

# %%
# Models that we will use
#       Model name ---------------------------------------------------------------------
#      Parameters ------------------------------------------                           |
#     Classifier -----------                               |                           |
#                          |                               |                           |
#                          v                               v                           |
models = [[tree.DecisionTreeClassifier(), {'min_samples_split': [1, 10, 100],#         |
                                           'min_samples_leaf': [1, 5, 10, 50],#        v
                                           'max_depth': [10, 30, 50, 100]},       "Decision Tree"]
          ]

models.append([])

models_with_best_params = []

for model in models:
    clf = GridSearchCV(model[0], model[1], cv=5)
    clf.fit(x_train[features], x_train['label'])
    best_params = clf.best_params_
    best_estimator = clf.best_estimator_
    
    model_with_best_params = [best_estimator, best_params, model[2]]
    
    models_with_best_params.append(model_with_best_params)

    print("Best parameters for ", model[2], " set found on development set:", best_params)
    print()
    print("Best estimator for ", model[2], " model:", best_estimator)
# print(clf_tree.best_params_)
# print()
# print("Grid scores on development set:")
# print()
# for params, mean_score, scores in clf_tree.grid_scores_:
#     print("%0.3f (+/-%0.03f) for %r"
#           % (mean_score, scores.std() * 2, params))
# print()

print(models_with_best_params)

# %%
#fitting models to test_data
for model in models_with_best_params:
    model[0].fit(x_train[features], x_train['label'])
    score = model[0].score(x_test[features], x_test['label'])
    print("Prediction accuracy for", model[2], "model is", score)
